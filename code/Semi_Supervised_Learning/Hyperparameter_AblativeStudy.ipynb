# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import category_encoders as ce
import matplotlib.pyplot as plt
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
loan_train = pd.read_csv('loan_train_sampled.csv')
loan_test = pd.read_csv('loan_test.csv')

# %% [markdown]
# ### Spliting the training data into labeled and unlabeled data

# %%
# Split labeled data into smaller labeled set and larger unlabeled set
labeled_data, unlabeled_data = train_test_split(loan_train, test_size=0.8, random_state=0)

# Separate test set for final evaluation
X_test = loan_test.loc[:, loan_test.columns != 'loan_status']

print("Labeled data shape:", labeled_data.shape)
print("Unlabeled data shape:", unlabeled_data.shape)
# Out:
# Labeled data shape: (3356, 39)
# Unlabeled data shape: (13424, 39)

# %%
iteration = 0

# %% [markdown]
# ### The model is trained on labeled data and the unlabeled data exhibiting high-confidence predictions (with high probabilities) with pseudo labels are added iteratively to the labeled data.
# ### Tuning the Hyperparameters for the Ablative Study

# %%
# Hyperparameters for the ablative study
min_samples_split = 5
min_samples_leaf = 10
splitter = 'best'
max_features = None
class_weight = None

while len(unlabeled_data) > 10:
    print("------------------ Iteration:", iteration + 1 , "------------------")
    print("Labeled data Shape:", labeled_data.shape)
    print("Unlabeled data Shape:", unlabeled_data.shape)
    
    # Labeled data
    y_train_labeled = labeled_data['loan_status']
    X_train_labeled = labeled_data.loc[:, labeled_data.columns != 'loan_status']
    features = X_train_labeled.columns.tolist()
    
    # Encode categorical columns
    categorical_columns = X_train_labeled.select_dtypes(include=['object']).columns.tolist()
    encoder = ce.OrdinalEncoder(cols=categorical_columns)
    X_train_labeled = encoder.fit_transform(X_train_labeled)
    
    # Train decision tree on labeled data
    #splitter='best', max_features=3,  class_weight={0: 1, 1: 2}
    clf = DecisionTreeClassifier(criterion='entropy', random_state=0, max_depth=7,
                                 min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf,
                                 splitter=splitter, max_features=max_features, class_weight=class_weight)
    clf.fit(X_train_labeled, y_train_labeled)
    
    # Predict labels for unlabeled data
    X_train_unlabeled = unlabeled_data.loc[:, unlabeled_data.columns != 'loan_status']
    X_train_unlabeled = encoder.transform(X_train_unlabeled)
    y_train_unlabeled = clf.predict(X_train_unlabeled)
    y_train_unlabeled_proba = clf.predict_proba(X_train_unlabeled)
    
    # Set confidence thresholds for pseudo-labeling
    confidence_threshold_low = 0.15
    confidence_threshold_high = 0.85
    
    # Identify observations with high confidence pseudo-labels
    high_confidence_indices = np.where(
        np.logical_or(y_train_unlabeled_proba[:, 0] >= confidence_threshold_high,
                      y_train_unlabeled_proba[:, 1] >= confidence_threshold_high)
    )[0]
   
    if len(high_confidence_indices) > 0:
        # Sort high-confidence observations by confidence score in descending order
        sorted_high_confidence_indices = np.argsort(-np.max(y_train_unlabeled_proba[high_confidence_indices], axis=1))
        
        # Select the top K high-confidence observations
        K = int(0.2 * len(high_confidence_indices))  # 10% of high-confidence observations
        selected_high_confidence_indices = sorted_high_confidence_indices[:K]
        high_confidence_data = unlabeled_data.iloc[selected_high_confidence_indices]    
        print("Unlabeled data exhibiting high-confidence predictions (with high probabilities): ", high_confidence_data.shape)

        high_confidence_labels = np.argmax(y_train_unlabeled_proba[selected_high_confidence_indices], axis=1)   
        high_confidence_labels_str = np.where(high_confidence_labels == 1, 'Fully Paid', 'Charged Off')
    
        # Create a new DataFrame with high_confidence_data and high_confidence_labels_str
        high_confidence_data_labeled = high_confidence_data.copy()
        high_confidence_data_labeled['loan_status'] = high_confidence_labels_str
    
        # Concatenate high_confidence_data_labeled with labeled_data
        labeled_data = pd.concat([labeled_data, high_confidence_data_labeled], ignore_index=True)
        print("Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities)", labeled_data.shape)
    
        # Remove selected high-confidence pseudo-labeled observations from the unlabeled set
        unlabeled_data = unlabeled_data.drop(high_confidence_data.index)
        print("Unlabeled data shape in the end of this iteration", unlabeled_data.shape)
    else:
        print("No high-confidence observations found.")
    
    iteration += 1
# Out:
# ------------------ Iteration: 1 ------------------
# Labeled data Shape: (3356, 39)
# Unlabeled data Shape: (13424, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (2662, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (6018, 39)
# Unlabeled data shape in the end of this iteration (10762, 39)
# ------------------ Iteration: 2 ------------------
# Labeled data Shape: (6018, 39)
# Unlabeled data Shape: (10762, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (2105, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (8123, 39)
# Unlabeled data shape in the end of this iteration (8657, 39)
# ------------------ Iteration: 3 ------------------
# Labeled data Shape: (8123, 39)
# Unlabeled data Shape: (8657, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (1693, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (9816, 39)
# Unlabeled data shape in the end of this iteration (6964, 39)
# ------------------ Iteration: 4 ------------------
# Labeled data Shape: (9816, 39)
# Unlabeled data Shape: (6964, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (1388, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (11204, 39)
# Unlabeled data shape in the end of this iteration (5576, 39)
# ------------------ Iteration: 5 ------------------
# Labeled data Shape: (11204, 39)
# Unlabeled data Shape: (5576, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (1100, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (12304, 39)
# Unlabeled data shape in the end of this iteration (4476, 39)
# ------------------ Iteration: 6 ------------------
# Labeled data Shape: (12304, 39)
# Unlabeled data Shape: (4476, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (883, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (13187, 39)
# Unlabeled data shape in the end of this iteration (3593, 39)
# ------------------ Iteration: 7 ------------------
# Labeled data Shape: (13187, 39)
# Unlabeled data Shape: (3593, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (710, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (13897, 39)
# Unlabeled data shape in the end of this iteration (2883, 39)
# ------------------ Iteration: 8 ------------------
# Labeled data Shape: (13897, 39)
# Unlabeled data Shape: (2883, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (570, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (14467, 39)
# Unlabeled data shape in the end of this iteration (2313, 39)
# ------------------ Iteration: 9 ------------------
# Labeled data Shape: (14467, 39)
# Unlabeled data Shape: (2313, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (457, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (14924, 39)
# Unlabeled data shape in the end of this iteration (1856, 39)
# ------------------ Iteration: 10 ------------------
# Labeled data Shape: (14924, 39)
# Unlabeled data Shape: (1856, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (370, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (15294, 39)
# Unlabeled data shape in the end of this iteration (1486, 39)
# ------------------ Iteration: 11 ------------------
# Labeled data Shape: (15294, 39)
# Unlabeled data Shape: (1486, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (296, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (15590, 39)
# Unlabeled data shape in the end of this iteration (1190, 39)
# ------------------ Iteration: 12 ------------------
# Labeled data Shape: (15590, 39)
# Unlabeled data Shape: (1190, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (237, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (15827, 39)
# Unlabeled data shape in the end of this iteration (953, 39)
# ------------------ Iteration: 13 ------------------
# Labeled data Shape: (15827, 39)
# Unlabeled data Shape: (953, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (190, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16017, 39)
# Unlabeled data shape in the end of this iteration (763, 39)
# ------------------ Iteration: 14 ------------------
# Labeled data Shape: (16017, 39)
# Unlabeled data Shape: (763, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (152, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16169, 39)
# Unlabeled data shape in the end of this iteration (611, 39)
# ------------------ Iteration: 15 ------------------
# Labeled data Shape: (16169, 39)
# Unlabeled data Shape: (611, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (121, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16290, 39)
# Unlabeled data shape in the end of this iteration (490, 39)
# ------------------ Iteration: 16 ------------------
# Labeled data Shape: (16290, 39)
# Unlabeled data Shape: (490, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (97, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16387, 39)
# Unlabeled data shape in the end of this iteration (393, 39)
# ------------------ Iteration: 17 ------------------
# Labeled data Shape: (16387, 39)
# Unlabeled data Shape: (393, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (78, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16465, 39)
# Unlabeled data shape in the end of this iteration (315, 39)
# ------------------ Iteration: 18 ------------------
# Labeled data Shape: (16465, 39)
# Unlabeled data Shape: (315, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (62, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16527, 39)
# Unlabeled data shape in the end of this iteration (253, 39)
# ------------------ Iteration: 19 ------------------
# Labeled data Shape: (16527, 39)
# Unlabeled data Shape: (253, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (50, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16577, 39)
# Unlabeled data shape in the end of this iteration (203, 39)
# ------------------ Iteration: 20 ------------------
# Labeled data Shape: (16577, 39)
# Unlabeled data Shape: (203, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (40, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16617, 39)
# Unlabeled data shape in the end of this iteration (163, 39)
# ------------------ Iteration: 21 ------------------
# Labeled data Shape: (16617, 39)
# Unlabeled data Shape: (163, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (32, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16649, 39)
# Unlabeled data shape in the end of this iteration (131, 39)
# ------------------ Iteration: 22 ------------------
# Labeled data Shape: (16649, 39)
# Unlabeled data Shape: (131, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (25, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16674, 39)
# Unlabeled data shape in the end of this iteration (106, 39)
# ------------------ Iteration: 23 ------------------
# Labeled data Shape: (16674, 39)
# Unlabeled data Shape: (106, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (20, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16694, 39)
# Unlabeled data shape in the end of this iteration (86, 39)
# ------------------ Iteration: 24 ------------------
# Labeled data Shape: (16694, 39)
# Unlabeled data Shape: (86, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (16, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16710, 39)
# Unlabeled data shape in the end of this iteration (70, 39)
# ------------------ Iteration: 25 ------------------
# Labeled data Shape: (16710, 39)
# Unlabeled data Shape: (70, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (13, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16723, 39)
# Unlabeled data shape in the end of this iteration (57, 39)
# ------------------ Iteration: 26 ------------------
# Labeled data Shape: (16723, 39)
# Unlabeled data Shape: (57, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (11, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16734, 39)
# Unlabeled data shape in the end of this iteration (46, 39)
# ------------------ Iteration: 27 ------------------
# Labeled data Shape: (16734, 39)
# Unlabeled data Shape: (46, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (9, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16743, 39)
# Unlabeled data shape in the end of this iteration (37, 39)
# ------------------ Iteration: 28 ------------------
# Labeled data Shape: (16743, 39)
# Unlabeled data Shape: (37, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (7, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16750, 39)
# Unlabeled data shape in the end of this iteration (30, 39)
# ------------------ Iteration: 29 ------------------
# Labeled data Shape: (16750, 39)
# Unlabeled data Shape: (30, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (5, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16755, 39)
# Unlabeled data shape in the end of this iteration (25, 39)
# ------------------ Iteration: 30 ------------------
# Labeled data Shape: (16755, 39)
# Unlabeled data Shape: (25, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (4, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16759, 39)
# Unlabeled data shape in the end of this iteration (21, 39)
# ------------------ Iteration: 31 ------------------
# Labeled data Shape: (16759, 39)
# Unlabeled data Shape: (21, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (4, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16763, 39)
# Unlabeled data shape in the end of this iteration (17, 39)
# ------------------ Iteration: 32 ------------------
# Labeled data Shape: (16763, 39)
# Unlabeled data Shape: (17, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (3, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16766, 39)
# Unlabeled data shape in the end of this iteration (14, 39)
# ------------------ Iteration: 33 ------------------
# Labeled data Shape: (16766, 39)
# Unlabeled data Shape: (14, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (2, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16768, 39)
# Unlabeled data shape in the end of this iteration (12, 39)
# ------------------ Iteration: 34 ------------------
# Labeled data Shape: (16768, 39)
# Unlabeled data Shape: (12, 39)
# Unlabeled data exhibiting high-confidence predictions (with high probabilities):  (2, 39)
# Shape of Labeled data after combining part of pseudo-labeled Data (with high probablities) (16770, 39)
# Unlabeled data shape in the end of this iteration (10, 39)

# %% [markdown]
# ### Decision Tree on test data

# %%
X_test = loan_test.loc[:, loan_test.columns != 'loan_status']
X_test = encoder.fit_transform(X_test)
y_test = loan_test['loan_status']

# Predict labels for the final test set
y_pred_final = clf.predict(X_test)

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf, 
                   feature_names=features,  
                   class_names=y_train_labeled.unique(),
                   filled=True)

# %% [markdown]
# ### Testing Data performance: Precisiom, Recall, F1-Score

# %%
print("====== Testing Data Confusion Matrix ======")
print(confusion_matrix(y_test, y_pred_final))
# Out:
# ====== Testing Data Confusion Matrix ======
# [[1552   81]
#  [   1 4975]]

# %%
print("====== Testing Data Classification Report ======")
print(classification_report(y_test, y_pred_final))
# Out:
# ====== Testing Data Classification Report ======
#               precision    recall  f1-score   support
#
#  Charged Off       1.00      0.95      0.97      1633
#   Fully Paid       0.98      1.00      0.99      4976
#
#     accuracy                           0.99      6609
#    macro avg       0.99      0.98      0.98      6609
# weighted avg       0.99      0.99      0.99      6609

# %% [markdown]
# ### Feature Importance

# %%
importance = clf.feature_importances_
for i,v in enumerate(importance):
 print(features[i],':', v)
# Out:
# loan_amnt : 0.0
# funded_amnt : 0.08356304211047501
# funded_amnt_inv : 0.00023202794255120114
# term : 0.0
# int_rate : 0.0
# grade : 0.0
# sub_grade : 0.00022998962047191267
# emp_length : 0.0
# home_ownership : 0.0
# annual_inc : 0.0
# verification_status : 0.0
# issue_d : 0.00033670653070581896
# purpose : 0.0
# title : 0.0
# addr_state : 0.0
# dti : 0.0
# delinq_2yrs : 0.0
# earliest_cr_line : 0.0
# inq_last_6mths : 0.0
# open_acc : 0.0
# pub_rec : 0.0
# revol_bal : 0.00043739000395486737
# revol_util : 0.0
# total_acc : 0.0
# out_prncp : 0.0
# out_prncp_inv : 0.0
# total_pymnt : 0.0
# total_pymnt_inv : 0.0010946673745628078
# total_rec_prncp : 0.1684827146830502
# total_rec_int : 0.00026570210660084635
# total_rec_late_fee : 0.0
# recoveries : 0.717570948852076
# collection_recovery_fee : 0.0
# last_pymnt_d : 0.0
# last_pymnt_amnt : 0.013584340357068143
# last_credit_pull_d : 0.014202470418483347
# collections_12_mths_ex_med : 0.0
# pub_rec_bankruptcies : 0.0

# %%
# plot feature importance
plt.figure(figsize=(12,8))
plt.bar(features, importance)
plt.xlabel('Feature')
plt.ylabel('Importance Score')
plt.xticks(rotation=90)
plt.title("Feature Importance")
plt.show()
